# %% [markdown]
# THEORY QUESTIONS:
#
# 1. What is the difference between a function and a method in Python?
#
# Ans: Function is structured reusable code which is utilize for carrying out special task whereas method the process of excuting task.
#
# syntx of function:
#
# def function_name(arguement):
#       """
#       ---
#       """
#       expression
#       return function_name
#
# Example:
#
# def add(x,y):
#
#     return x+y
#
# add(1,1)
#
# output: 2
#
#
#
# 2. Explain the concept of function arguments and parameters in Python.
#
# Ans: The variable or parameters which is passed while defining function is called as arguement. Function can have zero or more than 1 arguement at a time.
#
# For example:
#
# def add(*a): #* sign is used while defining multiple arguements
#
#     return a
#
# add(2,3,4)
#
# output: (2,3,4)
#
#
#
#
# 3. What are the different ways to define and call a function in Python?
#
# Ans:
#
# user defined function:
#
# syntax:
#
# def function():
#     do something #body of function
#
# Example:
#
# def greet(name):
#
#     print("welcome to python world", name)
#
# greet("reem")
#
# output: welcome to python world, reem
#
#
#
#
# 4. What is the purpose of the `return` statement in a Python function?
#
# Ans: 'return' determines the value that the function will return and if return is statement is not inclued it ended up returning none.
#
# For example:
#
# def sq(x):
#
#     return x**2
#
# sq(2)
#
# output: 4
#
# OR
#
# def sq(x):
#
#     x**2
#
# sq(2)
#
# output:
#
#
#
# 5. What are iterators in Python and how do they differ from iterables?
#
# Ans: An iterable is any python objects/sequentials/data structure i.e. capable of returning it's members one at a time, permitting it to be itterated over in a for loop. strings, lists, sets, tuples and ditctunaries are iterable.
#
# An iterator is an object representing a stream of data and return it only by one.
#
# Example:
#
# def sq(n):
#
#     result=[]
#
#     for i in range(n):
#
#           result.append(i*i)
#
#     return result
#
# sq(10)
#
# output: [0,1,4,9,16,25,36,49,64,81]
#
#
#
# 6. Explain the concept of generators in Python and how they are defined.
#
# Ans:
#
# Regular function calculates teh square of the values and return it in
# one go. Since, it is returning in one go and memory usage will be more and it will take a lot of execuation time if there is lot of computation as all the computation will be done first and then the calculations will be returned in one go. To overcome this problem we have generator function which generate result one-by-one instead in one go. General function uses return statement but a generator function uses yeild statement.
#
# Example:
#
# def sq(n):
#     for i in range(n):
#         yeild i*i
#
# sq(2)
#
# output: <generator object-------->
#
# next(sq)
#
# output: 0
#
# next(sq)
#
# 1
#
#
#
# 7. What are the advantages of using generators over regular functions?
#
# Ans: Regular function calculates teh square of the values and return it in
# one go. Since, it is returning in one go and memory usage will be more and it will take a lot of execuation time if there is lot of computation as all the computation will be done first and then the calculations will be returned in one go. To overcome this problem we have generator function which generate result one-by-one instead in one go. General function uses return statement but a generator function uses yeild statement.
#
# Example:
#
# def sq(n):
#     for i in range(n):
#         yeild i*i
#
# sq(2)
#
# output: <generator object-------->
#
# next(sq)
#
# output: 0
#
# next(sq)
#
# 1
#
#
#
#
# 8. What is a lambda function in Python and when is it typically used?
#
# Ans: LAMBDA:  Lambda functions are small, anonymous functions defined using the lambda keyword. They are used for creating small, throwaway functions without the need to formally define a function using def
#
# Example:
#
# sq=(lambda x: x*x)
#
# sq(3)
#
# output: 9
#
# USE: Rather than writter lengthy code, lambda provides short hand codes for it. It makes code simple, understandable and easy.
#
#
#
#
# 9. Explain the purpose and usage of the `map()` function in Python.
#
# And: MAP: The map function applies a given function to all items in an input iterable and returns an iterator with the results.
#
# Syntax:
#
# map(function, iterable)
#
# Example:
#
# l=[1,2,3,4]
#
# sq=map(lambda x: x*x, l)
#
# print(list(sq))
#
# output: [1,3,9,16]
#
# USE: map() function is used when all items in an iterable and get a new iterable with the results.
#
#
#
#
#
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# Ans:
#
# MAP: The map function applies a given function to all items in an input iterable and returns an iterator with the results.
#
# Syntax:
#
# map(function, iterable)
#
# Example:
#
# l=[1,2,3,4]
#
# sq=map(lambda x: x*x, l)
#
# print(list(sq))
#
# output: [1,3,9,16]
#
# REDUCDE: The reduce function from the functools module applies a given function cumulatively to the items of a sequence, from left to right, to reduce the sequence to a single value.
#
# Syntax:
#
# from functools import reduce
#
# reduce(function, iterable)
#
# Example:
#
# from functools import reduce
#
# l=[1,2,3,4,5,6]
#
# sum=reduce(lambda x,y: x+y, l)
#
# print(sum)
#
# output: 21
#
#
# FILTER: The filter function constructs an iterator from elements of an iterable for which a specified function returns True.
#
# Syntax:
#
# filter(function, iterable)
#
# Example:
#
# l=[1,2,3,4,6]
#
# even_num=filter(lambda x: x%2==0, l)
#
# print(list(even_num))
#
# output: [2,4,6]
#
#
#
#
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#
# Ans:

# %%
#PRACTICAL QUESTIONS:

#01) Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list?

def sum_even_num(a):
  sum=0
  for i in a:
    if i%2==0:
      sum=sum+i
  return sum

sum_even_num([1,2,3,4])
# Out:
# 6

# %%
#02) Create a Python function that accepts a string and returns the reverse of that string?

def reverse_string(a):
  n=[]
  for i in a:
    if type(i)==str:
      n.append(i[::-1])
  return n

reverse_string([1,2,3,4.5,"reem","ree"])
# Out:
# ['meer', 'eer']

# %%
#03) Implement a Python function that takes a list of integers and returns a new list containing the squares of each number?

def sq(a):
  n=[]
  for i in a:
    n.append(i*i)
  return n

sq([1,2,3,4,5])
# Out:
# [1, 4, 9, 16, 25]

# %%
#04) Write a Python function that checks if a given number is prime or not from 1 to 200?

def check(a):
  for i in a:
    if i<2:
      print(i,"is not prime")
    elif i%i==0:
      print(i, "is prime")
    elif i%i!=0:
      print(i, "is not prime")

check(range(201))
# Out:
# 0 is not prime
# 1 is not prime
# 2 is prime
# 3 is prime
# 4 is prime
# 5 is prime
# 6 is prime
# 7 is prime
# 8 is prime
# 9 is prime
# 10 is prime
# 11 is prime
# 12 is prime
# 13 is prime
# 14 is prime
# 15 is prime
# 16 is prime
# 17 is prime
# 18 is prime
# 19 is prime
# 20 is prime
# 21 is prime
# 22 is prime
# 23 is prime
# 24 is prime
# 25 is prime
# 26 is prime
# 27 is prime
# 28 is prime
# 29 is prime
# 30 is prime
# 31 is prime
# 32 is prime
# 33 is prime
# 34 is prime
# 35 is prime
# 36 is prime
# 37 is prime
# 38 is prime
# 39 is prime
# 40 is prime
# 41 is prime
# 42 is prime
# 43 is prime
# 44 is prime
# 45 is prime
# 46 is prime
# 47 is prime
# 48 is prime
# 49 is prime
# 50 is prime
# 51 is prime
# 52 is prime
# 53 is prime
# 54 is prime
# 55 is prime
# 56 is prime
# 57 is prime
# 58 is prime
# 59 is prime
# 60 is prime
# 61 is prime
# 62 is prime
# 63 is prime
# 64 is prime
# 65 is prime
# 66 is prime
# 67 is prime
# 68 is prime
# 69 is prime
# 70 is prime
# ...

# %%
#05) Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms?

# %%
#06) Write a generator function in Python that yields the powers of 2 up to a given exponent?

# %%
#07) Implement a generator function that reads a file line by line and yields each line as a string?

# %%
#08) Use a lambda function in Python to sort a list of tuples based on the second element of each tuple?

x=("sheena","ree","raaj","ajay")
sor=sorted(x, key=lambda x: x[1])
print(sor)
# Out:
# ['raaj', 'ree', 'sheena', 'ajay']

# %%
#09) Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit?

l=[20, 40, 50, 60] #temperature in celsius
list(map(lambda x: (x*(9/5)+32),l))
# Out:
# [68.0, 104.0, 122.0, 140.0]

# %%
#10) Create a Python program that uses `filter()` to remove all the vowels from a given string?

''.join(list(filter(lambda x: x not in "aeiouAEIOU", "reem")))
# Out:
# 'rm'

# %%
#11)
"""" Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
order is smaller than 100,00 €.
Write a Python program using lambda and map.
"""

order = [[34587, ("Learning Python, Mark Lutz", 4, 40.95)],
          [98762, ("Programming Python, Mark Lutz", 5, 56.80)],
          [77226, ("Head First Python, Paul Barry", 3, 32.95)],
          [88112, ("Einführung in Python3, Bernd Klein", 3, 24.99)]]

processed_orders = list(map(lambda x: (x[0], x[1][1] * x[1][2] + (10 if x[1][1] * x[1][2] < 100 else 0)), order))

print(processed_orders)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
